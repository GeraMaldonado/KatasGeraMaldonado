# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('D:\Escritorio\Launch X\Modulo2Katas.png'))
display.display(Image.open('D:\Escritorio\Launch X\Modulo2Katas1.png'))
display.display(Image.open('D:\Escritorio\Launch X\Modulo2Katas2.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=979x512 at 0x1874C2D6440>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1280x984 at 0x1874BECB7C0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1280x984 at 0x1874C2D5B10>
